# %% [markdown]
# # список версий мак ос

# %% [markdown]
# - macOS Monterey 12 - 7 июня 2021 г
# - macOS Big Sur 11 - 12 ноября 2020
# - macOS Catalina 10.15 - 3 июня 2019
# - macOS Mojave 10.14 - 24 сентября 2018 года
#     - ---
# - macOS High Sierra 10.13 - 25 сентября 2017
# - macOS Sierra 10.12 - 13 июня 2016 года (не путать с Mac OS)
#
# - OS X El Capitan 10.11 - 8 июня 2015 года
#     - Только МАК
# - OS X Yosemite 10.10 - 17 октября 2014 года
#     - Только МАК

# %% [markdown]
# - OS X Mavericks 10.9 - 10 июня 2013 года
#     - iMac (Mid 2007 or later); MacBook (Aluminum, Late 2008 or later); MacBook Air (Late 2008 or later); MacBook Pro (Mid 2007 or later); Mac Mini (Early 2009 or later); Mac Pro (Early 2008 or later); Xserve (Early 2009);
# - OS X Mountain Lion 10.8 - 25 июля 2012 года
#     - iMac (Mid 2007 or later); MacBook (Aluminum, Late 2008 or later); MacBook Air (Late 2008 or later); MacBook Pro (Mid 2007 or later); Mac Mini (Early 2009 or later); Mac Pro (Early 2008 or later); Xserve (Early 2009);

# %% [markdown]
# - OS X Lion 10.7 - 20 июля 2011 года
#     - ПРОЦЕССОР x86-64 (64-разрядные компьютеры Mac с процессором Intel Core 2 Duo, Intel Core i5, Intel Core i7 или Xeon.)
# - Mac OS X Snow Leopard 10.6 - June 8, 2009
#     - Требуется компьютер Mac с графическим 64-разрядным процессором.
#     - CUPS (the printing system used in many Unix-like operating systems) has been updated to version 1.4 which provides improved driver, networking, and Kerberos support along with performance improvements. CUPS 1.4 is also the first implementation of the Internet Printing Protocol version 2.1.[56]
# - Mac OS X Leopard 10.5 - 26 October 2007
#     - Mac OS X 10.5. Sonnet Tech
# - Mac OS X Tiger 10.4 - April 29, 2005.
#     - Processor: PowerPC G3, G4 or G5.

# %% [markdown]
# - Mac OS X Panther 10.3 - October 8, 2003 an
#     - PowerPC G3, G4, or G5 processor
# - Mac OS X 10.2 Jaguar - (10.2.0 - August 24, 2002)(10.2.1 - September 18, 2002)
#     - процессорPowerPC G3, PowerPC G5.
# - Mac OS X 10.1 Puma - 25 September 2001
#     - ПК: Power Mac G3, G4, G4 Cube, iMac G3, DV, eMac, PowerBook или iBook
# - Mac OS X 10.0 Cheetah - в 2001 год. -  ЦП?
#     - Power Macintosh G3, G3 B&W, G4, G4 Cube, iMac, PowerBook G3, PowerBook G4, iBook

# %% [markdown]
# # Как преобразовать DMG в ISO — 5 способов
#
# https://vellisa.ru/convert-dmg-to-iso
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# После настроить виртуальную машину...
#
# После добавить настройки через консоль
#
# После запустить на установку

# %%
# %%cmd
# cd C:\Program Files\Oracle\VirtualBox\
# echo %cd%
# Explorer C:\Program Files\Oracle\VirtualBox\
# Out:
# Microsoft Windows [Version 10.0.19045.4894]
# (c) ��௮��� �������� (Microsoft Corporation). �� �ࠢ� ���饭�.
#
# C:\Users\SibNout2023\WorkPlate\GitHubOll\MacOS_QWE>cd C:\Program Files\Oracle\VirtualBox\
#
# C:\Program Files\Oracle\VirtualBox>echo %cd%
# C:\Program Files\Oracle\VirtualBox
#
# C:\Program Files\Oracle\VirtualBox>Explorer C:\Program Files\Oracle\VirtualBox\
#
# C:\Program Files\Oracle\VirtualBox>

# %%
# !start "C:\Program Files\Oracle\VirtualBox\VirtualBox.exe"

# %%
# %%cmd
# cd C:\Program Files\Oracle\VirtualBox\
# echo %cd%
#
# VBoxManage.exe modifyvm "MACOS" --cpuidset 00000001 000106e5 00100800 0098e3fd bfebfbff
# VBoxManage setextradata "MACOS" "VBoxInternal/Devices/efi/0/Config/DmiSystemProduct" "iMac11,3"
# VBoxManage setextradata "MACOS" "VBoxInternal/Devices/efi/0/Config/DmiSystemVersion" "1.0"
# VBoxManage setextradata "MACOS" "VBoxInternal/Devices/efi/0/Config/DmiBoardProduct" "Iloveapple"
# VBoxManage setextradata "MACOS" "VBoxInternal/Devices/smc/0/Config/DeviceKey" "ourhardworkbythesewordsguardedpleasedontsteal(c)AppleComputerInc"
# VBoxManage setextradata "MACOS" "VBoxInternal/Devices/smc/0/Config/GetKeyFromRealSMC" 1
# Out:
# Microsoft Windows [Version 10.0.19045.4894]
# (c) ��௮��� �������� (Microsoft Corporation). �� �ࠢ� ���饭�.
#
# C:\Users\SibNout2023\WorkPlate\GitHubOll\MacOS_QWE>cd C:\Program Files\Oracle\VirtualBox\
#
# C:\Program Files\Oracle\VirtualBox>echo %cd%
# C:\Program Files\Oracle\VirtualBox
#
# C:\Program Files\Oracle\VirtualBox>
# C:\Program Files\Oracle\VirtualBox>VBoxManage.exe modifyvm "MACOS" --cpuidset 00000001 000106e5 00100800 0098e3fd bfebfbff
#
# C:\Program Files\Oracle\VirtualBox>VBoxManage setextradata "MACOS" "VBoxInternal/Devices/efi/0/Config/DmiSystemProduct" "iMac11,3"
#
# C:\Program Files\Oracle\VirtualBox>VBoxManage setextradata "MACOS" "VBoxInternal/Devices/efi/0/Config/DmiSystemVersion" "1.0"
#
# C:\Program Files\Oracle\VirtualBox>VBoxManage setextradata "MACOS" "VBoxInternal/Devices/efi/0/Config/DmiBoardProduct" "Iloveapple"
#
# ...
